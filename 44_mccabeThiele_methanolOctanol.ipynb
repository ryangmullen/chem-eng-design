# %%
################################################################################
# IMPORT MODULES
################################################################################
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import intersect

################################################################################
# DEFINE CONSTANTS
################################################################################
# Internal Units
# Pressure: Pa
# Temperature: K
# Flowrates: mol/s

# universal constants
Rg = 8.314
Po = 101325 # Pa, atmospheric pressure
To = 298.15

# unit conversions
bar_to_Pa = 1.e5
degC_to_K = 273.15
u_to_k = 1.e-3
ft_to_m = 0.3048
k_to_u = 1.e3
hr_to_s = 3600.

# operating conditions
P = Po

# physical properties
antoine = {'meoh':(81.768,-6876,-8.7078,7.1926e-6,2),
           'octoh':(155.87,-14283,-18.537,1.3192e-17,6)}
mw = np.array([32.04,130.23])*u_to_k

################################################################################
# DEFINE FUNCTIONS
################################################################################
def Psat(T,params,dT=10):
  A,B,C,D,E = params
  Psat = np.exp(A + B/T+C*np.log(T) + D*T**E)
  return Psat

def dP(T,P,parms):
  return Psat(T,parms) - P

def idealx(T,P,x,parms1,parms2):
  return P - x*Psat(T,parms1) - (1-x)*Psat(T,parms2)

def idealy(T,P,y,parms1,parms2):
  return 1 - y*P/Psat(T,parms1) - (1-y)*P/Psat(T,parms2)

def underwood(theta,z,q,alpha):
  return 1 - q - alpha*z/(alpha-theta) - (1-z)/(1-theta)

def gilliland(Y,X):
  return Y - 1 + np.exp((1+54.4*X)/(11+117.2*X)*(X-1)/(np.sqrt(X)))

################################################################################
# FILE MANAGEMENT
################################################################################
# check for required input files
Txy,Pxy,x1,y1 = np.loadtxt('20_mccabeThiele_methanolOctanol_srk.csv',delimiter=',').T

# create output files
outFile = '20_mccabeThiele_methanolOctanol'

# %%
################################################################################
# PURE COMPONENT PROPERTIES
################################################################################
Tmin = opt.root(dP,To,args=(P,antoine['meoh'])).x[0]
Tmax = opt.root(dP,200+degC_to_K,args=(P,antoine['octoh'])).x[0]

nPts = 100
T = np.linspace(Tmin,Tmax,nPts)
P1 = np.array([Psat(T[i],antoine['meoh']) for i in range(nPts)])
P2 = np.array([Psat(T[i],antoine['octoh']) for i in range(nPts)])

plt.plot(T-degC_to_K,P1/bar_to_Pa,label='meoh')
plt.plot(T-degC_to_K,P2/bar_to_Pa,label='octoh')
plt.xlabel('Temperature, $T$ (°C)')
plt.ylabel('Pressure, $P$ (bar)')
plt.legend()
plt.show()

# %%
################################################################################
# DEFINE CONSTANTS
################################################################################
# feed flow and quality
F = np.array([75,25]) * k_to_u/hr_to_s
q = 0.7

# purity
DbyF = np.array([0.9999,0.001]) # [light key split, heavy key split]

# reflux ratio
Rmin = 0.1
RByRmin = 1.2

################################################################################
# MAIN CODE
################################################################################
print('Feed')
print('  F = %.3g kmol/hr' % (sum(F)*hr_to_s/k_to_u))
z = F[0]/sum(F)
print('  z1 = %.3g' % z)
print('  q = %.3g' % q)

print('\nTops')
D = DbyF*F
print('  D = %.3g kmol/hr' % (sum(D)*hr_to_s/k_to_u))
yD = D[0]/sum(D)
print('  y1 = %.4g' % yD)

print('\nBottoms')
B = F-D
print('  B = %.3g kmol/hr' % (sum(B)*hr_to_s/k_to_u))
xB = B[0]/sum(B)
print('  x1 = %.4g' % xB)

print('\nFenske-Underwood-Gilliland')
# Fenske Equation (Table 11.13.7)
alphaD = P1[0]/P2[0]
alphaB = P1[-1]/P2[-1]
alpha = np.sqrt(alphaD*alphaB)
print('  alpha = %.3g' % (alpha))

Nmin = np.log((yD/(1-yD))/(xB/(1-xB)))/np.log(alpha)
print('  Nmin  = %.3g' % Nmin)

# Underwood Equation
print('')
theta = opt.root(underwood,(alpha+1)/2,args=(z,q,alpha)).x
print('  theta = %.3g' % theta)
Rm = alpha*yD/(alpha-theta) + (1-yD)/(1-theta) - 1
print('  Rmin  = %.3g' % Rm)

# Gilliland Equation
print('')
R = max(Rmin,RByRmin*Rm)
print('  R = %.3g' % R)
X = (R-Rm)/(R+1)
Y0 = 0.5
Y = opt.root(gilliland,Y0,args=(X)).x
N = (Y + Nmin)/(1 - Y)
print('  N = %.3g' % N)
# Out:
# Feed
#   F = 100 kmol/hr
#   z1 = 0.75
#   q = 0.7
#
# Tops
#   D = 75 kmol/hr
#   y1 = 0.9997
#
# Bottoms
#   B = 25 kmol/hr
#   x1 = 0.0003002
#
# Fenske-Underwood-Gilliland
#   alpha = 113
#   Nmin  = 3.41
#
#   theta = -171
#   Rmin  = -0.602
#
#   R = 0.1
#   N = 4.32

# %%
################################################################################
# McCABE-THIELE
################################################################################
nPts = 1001
x = np.linspace(0,1,nPts)

# feed line
xF = np.zeros(2)+z
yF = np.zeros(2)+z
if q == 1:
    xF[1] = z
    yF[1] = np.interp(xF[0],x1,y1)
else:
    mF = q / (q-1)
    bF = z - mF*z
    xF[1],yF[1] = intersect.intersection(x1,y1,x,mF*x+bF)
mmin = (yD-yF[1])/(yD-xF[1])
Rm = mmin / (1-mmin)

print('Rmin = %.3g' % Rm)
R = max(Rmin,RByRmin*Rm)
print('R = %.3g' % R)

# enriching line
mE = R/(R+1) # slope
bE = yD - mE*yD
xE = np.array([yD,xF[1]])
yE = mE*xE+bE

# need the intersection of feed and enriching
xF[1],yF[1] = intersect.intersection(xF,yF,xE,yE)
xE = np.array([yD,xF[1]])
yE = np.array([yD,yF[1]])

print('\nFeed line:')
print('  (%.4f,%.4f) --> (%.4f,%.4f)' % (xF[0],yF[0],xF[1],yF[1]))

print('\nEnriching line:')
print('  (%.4f,%.4f) --> (%.4f,%.4f)' % (xE[0],yE[0],xE[1],yE[1]))

# stripping line
xS = np.array([xB,xF[1]])
yS = np.array([xB,yF[1]])
mS = (yS[1]-yS[0])/(xS[1]-xS[0])
bS = yS[0] - mS*xS[0]

print('\nStripping line:')
print('  (%.4f,%.4f) --> (%.4f,%.4f)' % (xS[0],yS[0],xS[1],yS[1]))


# stages
print('\nStepping off stages:')
xMT = [yD]
yMT = [yD]
N = 0
while xMT[-1] > xB:
    # go to equilibrium line
    yMT.append(yMT[-1])
    xMT.append(np.interp(yMT[-1],y1,x1))
    # go to operating line
    xMT.append(xMT[-1])
    if xMT[-1] > xF[-1]:
        # go to enriching line
        yMT.append(np.interp(xMT[-1],x,mE*x+bE))
    else:
        # go to stripping line
        yMT.append(np.interp(xMT[-1],x,mS*x+bS))
    N += 1
    print('  %2d (%.4g,%.4g)' % (N,xMT[-2],yMT[-2]))
# Out:
# Rmin = 0.00823
# R = 0.1
#
# Feed line:
#   (0.7500,0.7500) --> (0.6564,0.9685)
#
# Enriching line:
#   (0.9997,0.9997) --> (0.6564,0.9685)
#
# Stripping line:
#   (0.0003,0.0003) --> (0.6564,0.9685)
#
# Stepping off stages:
#    1 (0.987,0.9997)
#    2 (0.874,0.9985)
#    3 (0.3511,0.9882)
#    4 (0.02778,0.518)
#    5 (0.00173,0.04085)
#    6 (0.000102,0.00241)

# %%
################################################################################
# McCABE-THIELE
################################################################################
plt.figure(dpi=300)
plt.plot(x,x,'k-',lw=1)
plt.xlabel(r'liquid mole fraction, $x_1$')
plt.xlim(0,1)
plt.ylabel(r'vapor mole fraction, $y_1$')
plt.ylim(0,1)

# equilibrium compositions
plt.plot(x1,y1,'r-',lw=3)

# feed line
plt.plot(z,z,'bo',markersize=5)
plt.plot(xF,yF,'b-',lw=1)

# enriching line
plt.plot(yD,yD,'bo',markersize=5)
plt.plot(xE,yE,'b-',lw=1)

# stripping line
plt.plot(xS,yS,'b-',lw=1)
plt.plot(xB,xB,'bo',markersize=5)

# stages
plt.plot(xMT,yMT,'k-',lw=1)
plt.text(0.6,0.05,'Methanol(1)-Octanol(2)')
plt.savefig(outFile + '.png')

# %%
plt.figure(dpi=300)
plt.plot(x,x,'k-',lw=1)
plt.xlabel(r'liquid mole fraction, $x_1$')
plt.xlim(0.8,1)
plt.ylabel(r'vapor mole fraction, $y_1$')
plt.ylim(0.98,1)

# equilibrium compositions
plt.plot(x1,y1,'r-',lw=3)

# feed line
plt.plot(z,z,'bo',markersize=5)
plt.plot(xF,yF,'b-',lw=1)

# enriching line
plt.plot(yD,yD,'bo',markersize=5)
plt.plot(xE,yE,'b-',lw=1)

# stripping line
plt.plot(xS,yS,'b-',lw=1)
plt.plot(xB,xB,'bo',markersize=5)

# stages
plt.plot(xMT,yMT,'k-',lw=1)
plt.savefig(outFile + '.top.png')

# %%
plt.figure(dpi=300)
plt.plot(x,x,'k-',lw=1)
plt.xlabel(r'liquid mole fraction, $x_1$')
plt.xlim(0.,0.035)
plt.ylabel(r'vapor mole fraction, $y_1$')
plt.ylim(0.,0.035)

# equilibrium compositions
plt.plot(x1,y1,'r-',lw=3)

# feed line
plt.plot(z,z,'bo',markersize=5)
plt.plot(xF,yF,'b-',lw=1)

# enriching line
plt.plot(yD,yD,'bo',markersize=5)
plt.plot(xE,yE,'b-',lw=1)

# stripping line
plt.plot(xS,yS,'b-',lw=1)
plt.plot(xB,xB,'bo',markersize=5)

# stages
plt.plot(xMT,yMT,'k-',lw=1)
plt.savefig(outFile + '.bottom.png')

# %%
print('\n1) Molar Flow Rates:')
L = np.zeros(2)
V = np.zeros(2)
L[0] = R*sum(D)
V[0] = L[0]+sum(D)
print('  V    = %.3g kmol/hr' % (V[0]*hr_to_s/k_to_u))
print('  L    = %.3g kmol/hr' % (L[0]*hr_to_s/k_to_u))
L[1] = q*sum(F) + L[0]
V[1] = V[0] - sum(F)*(1-q)
print('  Vbar = %.3g kmol/hr' % (V[1]*hr_to_s/k_to_u))
print('  Lbar = %.3g kmol/hr' % (L[1]*hr_to_s/k_to_u))
print('  Vbar/B = %.3g' % (V[1]/sum(B)))

print('\n2) Densities:')
T = np.array([Tmin,Tmax])
rho_V = P*mw/Rg/T
print('  rho_V    = %.3g kg/m^3' % rho_V[0])
print('  rho_Vbar = %.3g kg/m^3' % rho_V[1])
rho_L = np.array([772,830])
print('  rho_L    = %.3g kg/m^3' % rho_L[0])
print('  rho_Lbar = %.3g kg/m^3' % rho_L[1])

print('\n3) Liquid/Vapor:')
Flv = L/V*np.sqrt(rho_V/rho_L)
print('  F_LV    = %.3g' % Flv[0])
print('  F_LVbar = %.3g' % Flv[1])
# Out:
# 1) Molar Flow Rates:
#   V    = 82.5 kmol/hr
#   L    = 7.5 kmol/hr
#   Vbar = 52.5 kmol/hr
#   Lbar = 77.5 kmol/hr
#   Vbar/B = 2.1
#
# 2) Densities:
#   rho_V    = 1.16 kg/m^3
#   rho_Vbar = 3.39 kg/m^3
#   rho_L    = 772 kg/m^3
#   rho_Lbar = 830 kg/m^3
#
# 3) Liquid/Vapor:
#   F_LV    = 0.00352
#   F_LVbar = 0.0943

# %%
print('\n4) Flooding Parameters')
a,b,c = (0.94506,0.70234,0.22618)
Flv_i = np.logspace(-2,0.3)
Csb_i = 10**(-a-b*np.log10(Flv_i)-c*np.log10(Flv_i)**2)
Csb_max = np.max(Csb_i)
Flv_max = Flv_i[np.argmax(Csb_i)]
Csb = np.zeros(2)
for i,Flv_i in enumerate(Flv):
    if Flv_i < Flv_max:
        Csb[i] = Csb_max
    else:
        Csb[i] = 10**(-a-b*np.log10(Flv_i)-c*np.log10(Flv_i)**2)
print('  C_sb    = %.3g' % Csb[0])
print('  C_sbbar = %.3g' % Csb[1])

print('\n5) Flooding Velocity')
sigma = np.array([22.5,27.6]) # dynes/cm^2, surface tension
uf = Csb * (sigma/20)**0.2*np.sqrt((rho_L-rho_V)/rho_V)*ft_to_m
print('  u_f    = %.3g ft/s = %.3g m/s' % (uf[0]/ft_to_m,uf[0]))
print('  u_fbar = %.3g ft/s = %.3g m/s' % (uf[1]/ft_to_m,uf[1]))

print('\n6) Design Velocity')
uByuf = 0.75
u = uf*uByuf
print('  u    = %.3g ft/s = %.3g m/s' % (u[0]/ft_to_m,u[0]))
print('  ubar = %.3g ft/s = %.3g m/s' % (u[1]/ft_to_m,u[1]))


print('\n7) Active Area')
A = V*mw/rho_V/u
print('  A    = %.3g m^2' % A[0])
print('  Abar = %.3g m^2' % A[1])


print('\n8) Design Area')
AbyAT = 0.88
AT = A/AbyAT
print('  A_T    = %.3g m^2' % AT[0])
print('  A_Tbar = %.3g m^2' % AT[1])

print('\n9) Tower Diameter')
DT = np.sqrt(4/np.pi*AT)
print('  D_T    = %.3g m' % DT[0])
print('  D_Tbar = %.3g m' % DT[1])

print('\nCheck Flooding Fraction at Larger Diameter')
uc = V*mw/rho_V/A[0]
print('  At top diameter:')
print('    u/uf = %.2f' % (uc[0]/uf[0]))
print('    u/uf = %.2f' % (uc[1]/uf[1]))

uc = V*mw/rho_V/A[1]
print('  At bottom diameter:')
print('    u/uf = %.2f' % (uc[0]/uf[0]))
print('    u/uf = %.2f' % (uc[1]/uf[1]))
# Out:
# 4) Flooding Parameters
#   C_sb    = 0.398
#   C_sbbar = 0.345
#
# 5) Flooding Velocity
#   u_f    = 10.5 ft/s = 3.21 m/s
#   u_fbar = 5.74 ft/s = 1.75 m/s
#
# 6) Design Velocity
#   u    = 7.89 ft/s = 2.41 m/s
#   ubar = 4.31 ft/s = 1.31 m/s
#
# 7) Active Area
#   A    = 0.264 m^2
#   Abar = 0.427 m^2
#
# 8) Design Area
#   A_T    = 0.3 m^2
#   A_Tbar = 0.486 m^2
#
# 9) Tower Diameter
#   D_T    = 0.618 m
#   D_Tbar = 0.786 m
#
# Check Flooding Fraction at Larger Diameter
#   At top diameter:
#     u/uf = 0.75
#     u/uf = 1.21
#   At bottom diameter:
#     u/uf = 0.46
#     u/uf = 0.75

# %%
mu_F = 0.60
print('alpha*mu_F = %.3g cp' % (alpha*mu_F))
E0 = 53.977 - 22.527*np.log10(alpha*mu_F) + 3.07*np.log10(alpha*mu_F)**2 -11.0*np.log10(alpha*mu_F)**3
E0 = 52.782-27.511*np.log10(alpha*mu_F)+4.4923*np.log10(alpha*mu_F)**2
E0 /= 100
print('Efficiency, E0 = %.3g' % E0)

print('\nN_stages = %.d' % (N))
Ntrays = np.ceil((N - 1)/E0*1.1)
H = (Ntrays*2 + 10)*ft_to_m
print('N_trays = %d' % Ntrays)
print('Height, H = %.3g ft = %.3g m' % (H/ft_to_m,H))
print('H/D = %.3g' % (H/DT[1]))
# Out:
# alpha*mu_F = 67.8 cp
# Efficiency, E0 = 0.175
#
# N_stages = 6
# N_trays = 32
# Height, H = 74 ft = 22.6 m
# H/D = 28.7
